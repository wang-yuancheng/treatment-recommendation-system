# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting yellowbrick==1.5
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (23.0.1)
# Collecting xgboost==2.1.4
#   Downloading xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl (223.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 MB 5.1 MB/s eta 0:00:00
# Collecting statsmodels==0.14.4
#   Downloading statsmodels-0.14.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 110.7 MB/s eta 0:00:00
# Collecting lightgbm==4.6.0
#   Downloading lightgbm-4.6.0-py3-none-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 118.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.0.0 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.9.3)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 2)) (3.6.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied: cycler>=0.10.0 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: numpy>=1.16.0 in /root/venv/lib/python3.9/site-packages (from yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.25.2)
# Collecting nvidia-nccl-cu12
#   Downloading nvidia_nccl_cu12-2.26.2.post1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (291.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.7/291.7 MB 2.3 MB/s eta 0:00:00
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 38.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.14.4->-r ./requirements.txt (line 5)) (24.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.14.4->-r ./requirements.txt (line 5)) (2.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (11.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (4.56.0)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.4->-r ./requirements.txt (line 5)) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.4->-r ./requirements.txt (line 5)) (2025.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.9/site-packages (from scikit-learn>=1.0.0->yellowbrick==1.5->-r ./requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: joblib>=1.0.0 in /root/venv/lib/python3.9/site-packages (from scikit-learn>=1.0.0->yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick==1.5->-r ./requirements.txt (line 2)) (1.17.0)
# Installing collected packages: patsy, nvidia-nccl-cu12, xgboost, lightgbm, yellowbrick, statsmodels
# Successfully installed lightgbm-4.6.0 nvidia-nccl-cu12-2.26.2.post1 patsy-1.0.1 statsmodels-0.14.4 xgboost-2.1.4 yellowbrick-1.5
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
